# %%
import bokeh
import pandas as pd

# %%
print(bokeh.__version__)
# Out:
# 1.0.4

# %%
def process_data():

    # Import the Risk Dataset
    risk = pd.read_csv('#############/parkinsons/data/IHME-GBD_2017_DATA-All-Risks.csv')

    # cholesterol in YLDs
    chol = risk.loc[risk['rei_name'] == 'High LDL cholesterol']
    chol = chol.rename(columns={'val': 'cholesterol'})

    # Fasting Plasma Glucose in YLDs
    glucose = risk.loc[risk['rei_name'] == 'High fasting plasma glucose']
    glucose = glucose.rename(columns={'val': 'glucose'})

    # High body-mass index in YLDs
    bmi = risk.loc[risk['rei_name'] == 'High body-mass index']
    bmi = bmi.rename(columns={'val': 'bmi'})

    # Diet low in legumes in YLDs
    legumes = risk.loc[risk['rei_name'] == 'Diet low in legumes']
    legumes = legumes.rename(columns={'val': 'legumes'})

    # Diet low in fruits in YLDs
    fruits = risk.loc[risk['rei_name'] == 'Diet low in fruits']
    fruits = fruits.rename(columns={'val': 'fruits'})

    # Diet low in milk in YLDs
    milk = risk.loc[risk['rei_name'] == 'Diet low in milk']
    milk = milk.rename(columns={'val': 'milk'})

    # Diet low in whole grains in YLDs
    grains = risk.loc[risk['rei_name'] == 'Diet low in whole grains']
    grains = grains.rename(columns={'val': 'grains'})

    # Diet high in processed meat in YLDs
    meat = risk.loc[risk['rei_name'] == 'Diet high in processed meat']
    meat = meat.rename(columns={'val': 'processed_meat'})

    # Diet low in vegetables in YLDs
    veg = risk.loc[risk['rei_name'] == 'Diet low in vegetables']
    veg = veg.rename(columns={'val': 'veg'})

    # Diet high in sugar-sweetened beverages in YLDs
    sugar = risk.loc[risk['rei_name'] == 'Diet high in sugar-sweetened beverages']
    sugar = sugar.rename(columns={'val': 'sugar'})

    # Diet high in sodium in YLDs
    sodium = risk.loc[risk['rei_name'] == 'Diet high in sodium']
    sodium = sodium.rename(columns={'val': 'sodium'})

    # Merge risk dataset
    df_risk = pd.merge(chol[['location_name', 'sex_name', 'year', 'cholesterol']],
                       glucose[['location_name', 'sex_name', 'year', 'glucose']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       bmi[['location_name', 'sex_name', 'year', 'bmi']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       legumes[['location_name', 'sex_name', 'year', 'legumes']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       fruits[['location_name', 'sex_name', 'year', 'fruits']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       milk[['location_name', 'sex_name', 'year', 'milk']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       grains[['location_name', 'sex_name', 'year', 'grains']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       meat[['location_name', 'sex_name', 'year', 'processed_meat']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       veg[['location_name', 'sex_name', 'year', 'veg']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       sugar[['location_name', 'sex_name', 'year', 'sugar']],
                       on=['location_name', 'sex_name', 'year'])

    df_risk = pd.merge(df_risk,
                       sodium[['location_name', 'sex_name', 'year', 'sodium']],
                       on=['location_name', 'sex_name', 'year'])

    # Import the Direct Risk Dataset
    direct = pd.read_csv('#######/parkinsons/data/IHME-GBD_2017_DATA-direct_cause_PD.csv')

    # Smoking in YLDs
    smoking = direct.loc[direct['rei_name'] == 'Smoking']
    smoking = smoking.rename(columns={'val': 'smoking'})

    df_risk = pd.merge(df_risk,
                       smoking[['location_name', 'sex_name', 'year', 'smoking']],
                       on=['location_name', 'sex_name', 'year'])

    # Import the Parkinson's prevalence dataset
    cause = pd.read_csv('##########/parkinsons/data/IHME-GBD_2017_DATA-PD_Incidence_prevalence.csv')
    pv = cause.loc[cause["measure_id"] == 5]  # Prevalence of Parkinsons
    pv = pv.rename(columns={"val": "prevalence"})

    incidence = cause.loc[cause["measure_id"] == 6]  # Incidence of Parkinsons
    incidence = incidence.rename(columns={"val": "incidence"})

    df = pd.merge(df_risk,
                  pv[['location_name', 'sex_name', 'year', 'prevalence']],
                  on=['location_name', 'sex_name', 'year'])

    df = pd.merge(df,
                  incidence[['location_name', 'sex_name', 'year', 'incidence']],
                  on=['location_name', 'sex_name', 'year'])

    # Import the region dataset
    regions = pd.read_csv('######/parkinsons/data/region.csv')
    regions.rename({'Country': 'location_name'}, axis='columns', inplace=True)
    regions.rename({'Group': 'regions'}, axis='columns', inplace=True)

    # Merge the data and create a single df
    df = pd.merge(df,
                  regions,
                  on="location_name")

    a = ['Smoking']
    a.extend(risk.rei_name.unique())
    risk_list = sorted(a)

    return df, risk_list

# %%
df, risk_list = process_data()

# %%
df.T
# Out:
#                               0                    1                    2      \
# location_name                 China                China                China
# sex_name                       Male               Female                 Male
# year                           1990                 1990                 1991
# cholesterol              0.00632528           0.00627755           0.00642883
# glucose                   0.0439183            0.0331346            0.0445493
# bmi                       0.0144409            0.0138727            0.0149537
# legumes                 0.000348051          0.000397723           0.00035953
# fruits                    0.0156839            0.0134445            0.0159473
# milk                    8.27816e-05          6.51394e-05          8.57648e-05
# grains                    0.0170928            0.0143627            0.0174667
# processed_meat          5.54823e-05          2.18378e-05          5.86823e-05
# veg                      0.00462514           0.00484492            0.0046731
# sugar                   0.000159711          8.14861e-05          0.000170598
# sodium                    0.0147933            0.0150777            0.0150754
# smoking                   -0.249938           -0.0182646            -0.257166
# prevalence              0.000781259           0.00079353          0.000799234
# incidence               2.16639e-05          2.00188e-05          2.22186e-05
# regions         East Asia & Pacific  East Asia & Pacific  East Asia & Pacific
#
#                               3                    4                    5      \
# location_name                 China                China                China
# sex_name                     Female                 Male               Female
# year                           1991                 1992                 1992
# cholesterol              0.00641293           0.00654552           0.00655452
# glucose                   0.0339091            0.0452288            0.0346681
# bmi                       0.0143493            0.0155098            0.0148698
# legumes                 0.000412357           0.00037239          0.000428001
# fruits                    0.0136962            0.0162179            0.0139409
# milk                    6.71923e-05          8.87602e-05          6.91145e-05
# grains                    0.0147253            0.0178618            0.0150899
# processed_meat          2.32043e-05          6.26686e-05          2.48127e-05
# veg                      0.00490848              0.00472            0.0049673
# sugar                    8.6843e-05          0.000183706          9.32468e-05
# sodium                    0.0153685            0.0153965            0.0156793
# smoking                  -0.0190836            -0.264204           -0.0198775
# prevalence              0.000808789          0.000819413          0.000826319
# incidence               2.04614e-05          2.28356e-05          2.09601e-05
# regions         East Asia & Pacific  East Asia & Pacific  East Asia & Pacific
#
#                               6                    7                    8      \
# location_name                 China                China                China
# sex_name                       Male               Female                 Male
# year                           1993                 1993                 1994
# cholesterol              0.00666296           0.00670145           0.00679129
# glucose                   0.0459165            0.0353788            0.0466277
# bmi                       0.0160989            0.0154218            0.0167248
# legumes                 0.000385762          0.000444516          0.000399938
# fruits                    0.0164763            0.0141667            0.0167397
# milk                    9.13989e-05          7.09769e-05          9.40208e-05
# grains                    0.0182521            0.0154404             0.018635
# processed_meat          6.72948e-05          2.66588e-05          7.44107e-05
# veg                      0.00475367            0.0050135           0.00477936
# sugar                   0.000199066          0.000100658           0.00021934
# sodium                    0.0155811            0.0158595             0.015785
# smoking                   -0.270976             -0.02066            -0.277473
# prevalence              0.000840854          0.000845597          0.000864115
# incidence               2.34832e-05          2.14939e-05          2.41812e-05
# regions         East Asia & Pacific  East Asia & Pacific  East Asia & Pacific
#
#                               9      ...                       10910  \
# location_name                 China  ...                   Palestine
# sex_name                     Female  ...                        Male
# year                           1994  ...                        2013
# cholesterol              0.00685312  ...                  0.00489912
# glucose                   0.0360475  ...                   0.0509148
# bmi                       0.0160186  ...                   0.0456919
# legumes                 0.000461662  ...                 0.000443466
# fruits                     0.014398  ...                   0.0091375
# milk                    7.27584e-05  ...                 4.87791e-05
# grains                    0.0157742  ...                   0.0158866
# processed_meat           2.9672e-05  ...                 2.06115e-05
# veg                      0.00504927  ...                  0.00192219
# sugar                   0.000110584  ...                 0.000464319
# sodium                    0.0160456  ...                  0.00120003
# smoking                  -0.0213654  ...                   -0.102749
# prevalence              0.000865973  ...                 0.000401118
# incidence                2.2061e-05  ...                 9.50816e-06
# regions         East Asia & Pacific  ...  Middle East & North Africa
#
#                                      10911                       10912  \
# location_name                    Palestine                   Palestine
# sex_name                            Female                        Male
# year                                  2013                        2014
# cholesterol                     0.00535024                  0.00502677
# glucose                          0.0507453                   0.0518719
# bmi                              0.0544267                   0.0466951
# legumes                        0.000375657                 0.000450341
# fruits                          0.00914642                  0.00930984
# milk                           5.96921e-05                 4.97371e-05
# grains                           0.0155861                   0.0162004
# processed_meat                 1.12186e-05                 2.20313e-05
# veg                             0.00230822                  0.00195449
# sugar                          0.000302346                 0.000480747
# sodium                          0.00188602                  0.00122945
# smoking                        -0.00498553                   -0.103039
# prevalence                     0.000395244                 0.000411874
# incidence                      8.07788e-06                 9.72146e-06
# regions         Middle East & North Africa  Middle East & North Africa
#
#                                      10913                       10914  \
# location_name                    Palestine                   Palestine
# sex_name                            Female                        Male
# year                                  2014                        2016
# cholesterol                     0.00547471                  0.00534729
# glucose                          0.0516554                   0.0542366
# bmi                              0.0556203                   0.0490403
# legumes                        0.000381652                  0.00046949
# fruits                          0.00933833                  0.00971659
# milk                           5.99818e-05                 5.25714e-05
# grains                           0.0159176                   0.0169623
# processed_meat                 1.20911e-05                 2.35797e-05
# veg                             0.00234064                  0.00204026
# sugar                          0.000314394                  0.00051256
# sodium                          0.00191755                  0.00130358
# smoking                        -0.00490538                   -0.103532
# prevalence                     0.000402455                 0.000436061
# incidence                      8.20234e-06                 1.03631e-05
# regions         Middle East & North Africa  Middle East & North Africa
#
#                                      10915                       10916  \
# location_name                    Palestine                   Palestine
# sex_name                            Female                        Male
# year                                  2016                        2017
# cholesterol                     0.00576322                  0.00551187
# glucose                          0.0538336                   0.0554141
# bmi                              0.0583354                   0.0501641
# legumes                        0.000394414                 0.000478765
# fruits                          0.00973318                  0.00991461
# milk                           6.27846e-05                 5.45849e-05
# grains                           0.0166725                   0.0173462
# processed_meat                 1.29066e-05                 2.43298e-05
# veg                             0.00242686                    0.002083
# sugar                          0.000336937                 0.000528429
# sodium                          0.00199671                   0.0013411
# smoking                        -0.00473046                   -0.103769
# prevalence                     0.000419778                 0.000449038
# incidence                      8.55598e-06                  1.0694e-05
# regions         Middle East & North Africa  Middle East & North Africa
#
#                                      10917                       10918  \
# location_name                    Palestine                   Palestine
# sex_name                            Female                        Male
# year                                  2017                        2015
# cholesterol                     0.00592151                    0.005179
# glucose                          0.0550194                   0.0530673
# bmi                              0.0597631                   0.0478876
# legumes                        0.000401123                 0.000459525
# fruits                           0.0099552                  0.00950879
# milk                           6.44929e-05                 5.10895e-05
# grains                           0.0170892                   0.0165761
# processed_meat                 1.33347e-05                 2.28688e-05
# veg                             0.00247763                  0.00199606
# sugar                          0.000348841                 0.000496802
# sodium                          0.00204277                  0.00126478
# smoking                        -0.00464179                   -0.103316
# prevalence                     0.000429378                 0.000423594
# incidence                      8.74578e-06                 1.00468e-05
# regions         Middle East & North Africa  Middle East & North Africa
#
#                                      10919
# location_name                    Palestine
# sex_name                            Female
# year                                  2015
# cholesterol                     0.00561786
# glucose                          0.0527228
# bmi                              0.0569674
# legumes                        0.000388041
# fruits                          0.00953359
# milk                           6.14124e-05
# grains                           0.0162959
# processed_meat                 1.24865e-05
# veg                             0.00238516
# sugar                          0.000325547
# sodium                          0.00195467
# smoking                        -0.00481474
# prevalence                     0.000410714
# incidence                      8.37668e-06
# regions         Middle East & North Africa
#
# [18 rows x 10920 columns]

# %%
# Import the Direct Risk Dataset
direct = pd.read_csv('#######/parkinsons/data/IHME-GBD_2017_DATA-direct_cause_PD.csv')

direct
# Out:
#        measure_id                        measure_name  location_id  \
# 0               3  YLDs (Years Lived with Disability)           11
# 1               3  YLDs (Years Lived with Disability)           11
# 2               3  YLDs (Years Lived with Disability)           11
# 3               3  YLDs (Years Lived with Disability)           11
# 4               3  YLDs (Years Lived with Disability)           11
# 5               3  YLDs (Years Lived with Disability)           11
# 6               3  YLDs (Years Lived with Disability)           11
# 7               3  YLDs (Years Lived with Disability)           11
# 8               3  YLDs (Years Lived with Disability)           17
# 9               3  YLDs (Years Lived with Disability)           17
# 10              3  YLDs (Years Lived with Disability)           17
# 11              3  YLDs (Years Lived with Disability)           17
# 12              3  YLDs (Years Lived with Disability)           17
# 13              3  YLDs (Years Lived with Disability)           17
# 14              3  YLDs (Years Lived with Disability)           17
# 15              3  YLDs (Years Lived with Disability)           17
# 16              3  YLDs (Years Lived with Disability)           30
# 17              3  YLDs (Years Lived with Disability)           30
# 18              3  YLDs (Years Lived with Disability)           30
# 19              3  YLDs (Years Lived with Disability)           30
# 20              3  YLDs (Years Lived with Disability)           30
# 21              3  YLDs (Years Lived with Disability)           30
# 22              3  YLDs (Years Lived with Disability)           30
# 23              3  YLDs (Years Lived with Disability)           30
# 24              3  YLDs (Years Lived with Disability)           12
# 25              3  YLDs (Years Lived with Disability)           12
# 26              3  YLDs (Years Lived with Disability)           12
# 27              3  YLDs (Years Lived with Disability)           12
# 28              3  YLDs (Years Lived with Disability)           12
# 29              3  YLDs (Years Lived with Disability)           12
# ...           ...                                 ...          ...
# 43650           3  YLDs (Years Lived with Disability)          212
# 43651           3  YLDs (Years Lived with Disability)          212
# 43652           3  YLDs (Years Lived with Disability)          144
# 43653           3  YLDs (Years Lived with Disability)          144
# 43654           3  YLDs (Years Lived with Disability)          169
# 43655           3  YLDs (Years Lived with Disability)          169
# 43656           3  YLDs (Years Lived with Disability)          180
# 43657           3  YLDs (Years Lived with Disability)          180
# 43658           3  YLDs (Years Lived with Disability)          180
# 43659           3  YLDs (Years Lived with Disability)          180
# 43660           3  YLDs (Years Lived with Disability)          118
# 43661           3  YLDs (Years Lived with Disability)          118
# 43662           3  YLDs (Years Lived with Disability)          118
# 43663           3  YLDs (Years Lived with Disability)          118
# 43664           3  YLDs (Years Lived with Disability)          118
# 43665           3  YLDs (Years Lived with Disability)          118
# 43666           3  YLDs (Years Lived with Disability)          118
# 43667           3  YLDs (Years Lived with Disability)          118
# 43668           3  YLDs (Years Lived with Disability)           85
# 43669           3  YLDs (Years Lived with Disability)           85
# 43670           3  YLDs (Years Lived with Disability)           85
# 43671           3  YLDs (Years Lived with Disability)           85
# 43672           3  YLDs (Years Lived with Disability)           13
# 43673           3  YLDs (Years Lived with Disability)           13
# 43674           3  YLDs (Years Lived with Disability)           13
# 43675           3  YLDs (Years Lived with Disability)           13
# 43676           3  YLDs (Years Lived with Disability)           13
# 43677           3  YLDs (Years Lived with Disability)           13
# 43678           3  YLDs (Years Lived with Disability)           13
# 43679           3  YLDs (Years Lived with Disability)           13
#
#                   location_name  sex_id sex_name  age_id  age_name  cause_id  \
# 0                     Indonesia       1     Male      22  All Ages       544
# 1                     Indonesia       2   Female      22  All Ages       544
# 2                     Indonesia       1     Male      22  All Ages       544
# 3                     Indonesia       2   Female      22  All Ages       544
# 4                     Indonesia       1     Male      22  All Ages       544
# 5                     Indonesia       2   Female      22  All Ages       544
# 6                     Indonesia       1     Male      22  All Ages       544
# 7                     Indonesia       2   Female      22  All Ages       544
# 8                     Sri Lanka       1     Male      22  All Ages       544
# 9                     Sri Lanka       2   Female      22  All Ages       544
# 10                    Sri Lanka       1     Male      22  All Ages       544
# 11                    Sri Lanka       2   Female      22  All Ages       544
# 12                    Sri Lanka       1     Male      22  All Ages       544
